# %%
# %pip install ultralytics

# %%
from ultralytics import RTDETR

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="0tWfhJzq9INbGlrlyPIt")
project = rf.workspace("computervision-poxof").project("employee-performance-monitoring-m4ovu")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Employee-Performance-Monitoring-2 in yolov11:: 100%|██████████| 2936/2936 [00:00<00:00, 5802.40it/s]

# %%
model = RTDETR('rtdetr-l.pt')
model.info()
# Out:
# ...
# 100%|██████████| 63.4M/63.4M [00:00<00:00, 121MB/s]
# rt-detr-l summary: 449 layers, 32,970,476 parameters, 0 gradients, 108.3 GFLOPs
# (449, 32970476, 0, 108.3437056)

# %%
model.train(data="/content/Employee-Performance-Monitoring-2/data.yaml", epochs=100, imgsz=640)
# Out:
# Ultralytics 8.3.138 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model = RTDETR('/content/runs/detect/train/weights/best.pt')
print(model.names)
# Out:
# {0: 'Idle', 1: 'Not-Working', 2: 'Working'}

# %%
img_path = '/content/Employee-Performance-Monitoring-2/test/images/192-168-0-111_01_20220711172640988_jpg.rf.a4f5e8c7e200a49733d9d62adc45ff1c.jpg'
results = model.predict(img_path)
# Out:
# image 1/1 /content/Employee-Performance-Monitoring-2/test/images/192-168-0-111_01_20220711172640988_jpg.rf.a4f5e8c7e200a49733d9d62adc45ff1c.jpg: 640x640 4 Workings, 75.3ms
# Speed: 3.6ms preprocess, 75.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)

# %%
predicted_image_array = results[0].plot()

# Convert the numpy array to a displayable image format (PIL Image)
from PIL import Image

predicted_image = Image.fromarray(predicted_image_array[..., ::-1]) # Convert BGR to RGB

# Display the image
display(predicted_image)
# Out:
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
#Save model
result = model.export(format='onnx')
# Out:
# Ultralytics 8.3.138 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel CPUs. Learn more at https://docs.ultralytics.com/integrations/openvino/
# rt-detr-l summary: 302 layers, 31,989,905 parameters, 0 gradients, 103.4 GFLOPs
#
# PyTorch: starting from '/content/runs/detect/train/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 300, 7) (63.1 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0,<1.18.0', 'onnxslim>=0.1.53', 'onnxruntime-gpu'] not found, attempting AutoUpdate...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 310.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.2/146.2 kB 334.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.2/283.2 MB 203.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 196.9 MB/s eta 0:00:00
# ...
